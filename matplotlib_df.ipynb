# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# %%
ax=plt.subplot()

# %%
fig = plt.figure()
ax=fig.subplots(1,1)

# %%
fig, ax = plt.subplots()

# %%
x  = [1,2,3,4]
y=[11,22,33,44]
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
fig, ax=plt.subplots(figsize=(5,5))
ax.plot(x,y)
ax.set(title="plot",xlabel="xxx",ylabel="yyy")
# Out:
# [Text(0.5, 1.0, 'plot'), Text(0.5, 0, 'xxx'), Text(0, 0.5, 'yyy')]

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
price = {'a':10,"b":5,'c':20}
fig, ax= plt.subplots()
ax.bar(price.keys(),price.values())
ax.set(title="hdihd",ylabel="ydj");

# %%
price = {'a':10,"b":5,'c':20}
fig, ax= plt.subplots()
ax.barh(list(price.keys()),list(price.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.random.randn(100)
fig , ax= plt.subplots()
ax.hist(x);

# %%
y = np.random.random(100)
fig , ax= plt.subplots()
ax.hist(y);

# %%
#method 1
fig, ((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(price.keys(), price.values());
ax4.hist(np.random.randn(1000));

# %%
#method 2 
fig, ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x/2,x);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(price.keys(),price.values());
ax[1,1].hist(np.random.randn(1000));

# %%
data = pd.DataFrame({'Name':['ak','bk','ck','dk'],'Age':[20,40,36,56],'Score':[96,89,68,58]})
data
# Out:
#   Name  Age  Score
# 0   ak   20     96
# 1   bk   40     89
# 2   ck   36     68
# 3   dk   56     58

# %%
data["total score"]=data["Score"].cumsum()
data
# Out:
#   Name  Age  Score  total score
# 0   ak   20     96           96
# 1   bk   40     89          185
# 2   ck   36     68          253
# 3   dk   56     58          311

# %%
data.plot(x='Age',y='Score');

# %%
data.plot(x="Name",y="Age",kind="scatter",color='r')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.611852  0.070266  0.238668  0.672371
# 1  0.915142  0.937381  0.148410  0.191077
# 2  0.107624  0.841955  0.797107  0.265808
# 3  0.488559  0.309304  0.593479  0.002556
# 4  0.277474  0.469194  0.367562  0.427362
# 5  0.813324  0.639720  0.736658  0.768610
# 6  0.604338  0.915637  0.023208  0.218917
# 7  0.500743  0.568593  0.309235  0.219337
# 8  0.216173  0.406121  0.052902  0.094339
# 9  0.528960  0.693976  0.527553  0.242599

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data.plot.bar(x="Name",y="Age")
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
data["total score"].plot.hist(bins = 15,subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>], dtype=object)

# %%
data.plot(kind="scatter",x="Age",y="Score",c="total score")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Score'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df["a"],df['b'],df['c'],marker='*')
ax.set(title="hema")
fig.suptitle("dgu",fontweight='bold',fontsize=15)

ax.axhline(y=data["Age"].mean())

# %%
import math
math.ceil((20.45/100)*100)
# Out:
# 21

# %%
data
# Out:
#   Name  Age  Score  total score
# 0   ak   20     96           96
# 1   bk   40     89          185
# 2   ck   36     68          253
# 3   dk   56     58          311

# %%
def desired(x):
    bool_var = 'yes' if (x['Age']>30) else 'no'
    return bool_var

data["yes/no"]=data.apply(desired,axis=1)
data
# Out:
#   Name  Age  Score  total score yes/no
# 0   ak   20     96           96     no
# 1   bk   40     89          185    yes
# 2   ck   36     68          253    yes
# 3   dk   56     58          311    yes

# %%
import seaborn as sns

# %%
ax = sns.barplot(x="Age",y="Score",data=data)
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
